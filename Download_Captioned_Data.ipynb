# %% [markdown]
# ## Setting Up Credentials

# %%
# %cd ~
# %mkdir .aws
# !touch .aws/credentials

# %%
# %%writefile .aws/credentials
# [default]
# aws_access_key_id = AKIA3IMKISBF4X4JV2W7
# aws_secret_access_key = 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

# %%
# %cd -

# %% [markdown]
# ## Download Data

# %%
import boto3
import os

def downloadDirectory(bucket_name, remote_dir, limit=None):
    s3_resource = boto3.resource('s3')
    bucket = s3_resource.Bucket(bucket_name)
    count = 0
    for object in bucket.objects.filter(Prefix = remote_dir):
        if limit is not None and count == limit:
            break
        if object.key.split('/')[-1] != '':
            if not os.path.exists(os.path.dirname(object.key)):
                os.makedirs(os.path.dirname(object.key))
            bucket.download_file(object.key,object.key)
        count += 1

# %%
downloadDirectory('comp8755', 'Captions', limit=None)
